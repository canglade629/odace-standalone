# %%
# %sql
CREATE OR REPLACE TABLE odace.map.silver_accueillants AS 
SELECT 
  COALESCE(statut, 'Sans statut') AS statut,
  Ville,
  Code_postal,
  Latitude,
  Longitude
FROM odace.map.bronze_accueillants
